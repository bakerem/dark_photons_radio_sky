# %%
import os, sys

import matplotlib_inline
sys.path.append("../")

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import numpy as np

matplotlib_inline.backend_inline.set_matplotlib_formats('retina')

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Load plot settings
import healpy as hp
from plot_params import params
pylab.rcParams.update(params)

cols_default = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
post_ilc_map = hp.read_map("/projectnb/darkcosmo/dark_photon_project/21cmfast_cache/pyilc_alt_pt_src_0.1mJy_new_freq/clean_needlet_ILC_map_roman_20deg_LOFARthermal_mK.fits")
mask = hp.read_map("/usr3/graduate/ebaker/dark_photon_constraints/ilc/pyilc_files/roman_mask_20deg.fits")

# %%
new_prefac = 2* np.pi * 410e6 * 6.58212e-16 # convert MHz to eV

hp.gnomview(np.where(0==post_ilc_map*mask, np.nan, post_ilc_map/new_prefac), 
            unit=r"mK", 
            xsize=1690,  
            rot=(260, -70), 
            norm='hist', 
            cmap='plasma',
            notext=True,
            title=None,
            badcolor='white',)
plt.savefig("plots/post_ilc_map.pdf", bbox_inches='tight')
